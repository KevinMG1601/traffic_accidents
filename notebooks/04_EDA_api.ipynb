# %% [markdown]
# ## ***EDA API***

# %% [markdown]
# ### **Required libraries**

# %%
import sys
import os
project_path = os.path.abspath("../../traffic_accidents")
sys.path.append(project_path)

# %%
import pandas as pd

# %% [markdown]
# ### **Load data**

# %%
api = ("../data/api/accidents.csv")
df = pd.read_csv(api)
df.head(5)
# Out:
# /tmp/ipykernel_81489/1651678683.py:2: DtypeWarning: Columns (29,31,33,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(api)
#    caseyear  state  st_case statename  ve_total  ve_forms  pvh_invl  peds  \
# 0      2014      1    10001   Alabama         1         1         0     0
# 1      2014      1    10002   Alabama         1         1         0     0
# 2      2014      1    10003   Alabama         2         2         0     0
# 3      2014      1    10004   Alabama         3         3         0     0
# 4      2014      1    10005   Alabama         1         1         0     0
#
#    pernotmvit  permvit  ...  hosp_mn                        hosp_mnname cf1  \
# 0           0        2  ...       99  Unknown EMS Hospital Arrival Time   0
# 1           0        1  ...       99  Unknown EMS Hospital Arrival Time   0
# 2           0        7  ...       99  Unknown EMS Hospital Arrival Time   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98195 entries, 0 to 98194
# Data columns (total 94 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   caseyear      98195 non-null  int64
#  1   state         98195 non-null  int64
#  2   st_case       98195 non-null  int64
#  3   statename     98195 non-null  object
#  4   ve_total      98195 non-null  int64
#  5   ve_forms      98195 non-null  int64
#  6   pvh_invl      98195 non-null  int64
#  7   peds          98195 non-null  int64
#  8   pernotmvit    98195 non-null  int64
#  9   permvit       98195 non-null  int64
#  10  persons       98195 non-null  int64
#  11  county        98195 non-null  int64
#  12  countyname    98195 non-null  object
#  13  city          98195 non-null  int64
#  14  cityname      98195 non-null  object
#  15  day           98195 non-null  int64
#  16  dayname       0 non-null      float64
#  17  month         98195 non-null  int64
# ...

# %%
null_columns = df.columns[df.isnull().any(axis=0)]
print("Columns with null values:")
print(df[null_columns].isnull().sum())
# Out:
# Columns with null values:
# dayname         98195
# rur_urb         30343
# rur_urbname     30343
# func_sys        30343
# func_sysname    30343
# rd_owner        30343
# rd_ownername    30343
# tway_id2        72490
# road_fnc        67852
# road_fncname    67852
# dtype: int64

# %%
cols_nulos = [
    'rur_urb', 'rur_urbname',
    'func_sys', 'func_sysname',
    'rd_owner', 'rd_ownername',
    'tway_id2',
    'road_fnc', 'road_fncname'
]

for col in cols_nulos:
    print(f"Valores únicos en {col}:")
    print(df[col].unique(), "\n")
# Out:
# Valores únicos en rur_urb:
# [nan  1.  2.  6.  9.  8.]
#
# Valores únicos en rur_urbname:
# [nan 'Rural' 'Urban' 'Trafficway Not in State Inventory' 'Unknown'
#  'Not Reported']
#
# Valores únicos en func_sys:
# [nan  3.  1.  4.  5.  6.  2.  7. 96. 99. 98.]
#
# Valores únicos en func_sysname:
# [nan 'Principal Arterial - Other' 'Interstate' 'Minor Arterial'
#  'Major Collector' 'Minor Collector'
#  'Principal Arterial - Other Freeways and Expressways' 'Local'
#  'Trafficway Not in State Inventory' 'Unknown' 'Not Reported']
#
# Valores únicos en rd_owner:
# [nan  1.  2.  4.  3. 96. 99. 98. 62. 50. 26. 64. 40. 60. 25. 21. 31. 11.
#  66. 68. 12. 63. 74. 27. 32. 70. 67. 80.]
#
# Valores únicos en rd_ownername:
# [nan 'State Highway Agency' 'County Highway Agency'
#  'City or Municipal Highway Agency' 'Town or Township Highway Agency'
#  'Trafficway Not in State Inventory' 'Unknown' 'Not Reported'
#  'Bureau of Indian Affairs' 'Indian Tribe Nation'
# ...

# %%
duplicados = df.duplicated().sum()
print(f"Filas duplicadas: {duplicados}")
# Out:
# Filas duplicadas: 0

# %%
df.describe()
# Out:
#            caseyear         state        st_case      ve_total      ve_forms  \
# count  98195.000000  98195.000000   98195.000000  98195.000000  98195.000000
# mean    2015.047599     27.565324  276360.838220      1.547360      1.509965
# std        0.814466     16.308311  163005.209575      0.848257      0.808124
# min     2014.000000      1.000000   10001.000000      1.000000      1.000000
# 25%     2014.000000     12.000000  122035.500000      1.000000      1.000000
# 50%     2015.000000     27.000000  270364.000000      1.000000      1.000000
# 75%     2016.000000     42.000000  420762.000000      2.000000      2.000000
# max     2016.000000     56.000000  560131.000000     64.000000     64.000000
#
#            pvh_invl          peds    pernotmvit       permvit       persons  \
# count  98195.000000  98195.000000  98195.000000  98195.000000  98195.000000
# mean       0.037395      0.218300      0.227496      2.253720      2.262916
# ...

# %% [markdown]
# ### **DROP COLUMNS**

# %%
drop_columns = {
    'caseyear', 'dayname','hourname', 'minute','minutename','arr_hour',
    'arr_hourname','arr_min','arr_minname','hosp_hr','hosp_hrname','hosp_mn',
    'hosp_mnname','not_hour','not_hourname','not_min','not_minname','weather1',
    'weather2','weather2name','weather1name','weather','lgt_cond','state','statename',
    'city','cityname','county','countyname','latitude','latitudename','longitud',
    'longitudname','tway_id','rel_roadname','reljct2','reljct2name','reljct1',
    'typ_int','typ_intname','pvh_invl','peds','permvit','pernotmvit','drunk_dr',
    'man_coll','harm_ev','cf1','cf2','cf3','cf1name','cf2name','cf3name',
    'func_sys','func_sysname','road_fnc','route','routename','nhs','nhsname',
    'rd_owner','rd_ownername','st_case','rail','railname','wrk_zone','wrk_zonename',
    'sp_jur','sp_jurname','sch_bus','sch_busname','ve_forms','tway_id2','rur_urb',
    'rur_urbname','milept','mileptname','rel_road','road_fncname'
}

# %%
df_clean =df.drop(columns=drop_columns)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98195 entries, 0 to 98194
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ve_total      98195 non-null  int64
#  1   persons       98195 non-null  int64
#  2   day           98195 non-null  int64
#  3   month         98195 non-null  int64
#  4   monthname     98195 non-null  object
#  5   year          98195 non-null  int64
#  6   day_week      98195 non-null  int64
#  7   day_weekname  98195 non-null  object
#  8   hour          98195 non-null  int64
#  9   harm_evname   98195 non-null  object
#  10  man_collname  98195 non-null  object
#  11  reljct1name   98195 non-null  object
#  12  lgt_condname  98195 non-null  object
#  13  weathername   98195 non-null  object
#  14  fatals        98195 non-null  int64
# dtypes: int64(8), object(7)
# memory usage: 11.2+ MB

# %% [markdown]
# ### **Save CSV**

# %%
df_clean.to_csv("../data/api/accidents_clean.csv", index=False)
print("DataFrame limpio guardado como accidents_clean.csv")
# Out:
# DataFrame limpio guardado como accidents_clean.csv
